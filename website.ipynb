# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\izzat\appdata\roaming\python\python39\site-packages (1.10.0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: attrs in c:\python39\lib\site-packages (from streamlit) (21.4.0)
# Requirement already satisfied: blinker in c:\python39\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: click>=7.0 in c:\python39\lib\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (4.11.4)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from streamlit) (1.22.3)
# Requirement already satisfied: packaging in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pandas>=0.21.0 in c:\python39\lib\site-packages (from streamlit) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from streamlit) (9.1.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\python39\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (8.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: pympler>=0.9 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests in c:\python39\lib\site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: toml in c:\python39\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (6.1)
# Requirement already satisfied: tzlocal in c:\python39\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: validators in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: typing-extensions in c:\python39\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: semver in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: rich in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (12.4.4)
# Requirement already satisfied: watchdog in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: entrypoints in c:\users\izzat\appdata\roaming\python\python39\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\python39\lib\site-packages (from altair>=3.2.0->streamlit) (4.6.0)
# Requirement already satisfied: toolz in c:\users\izzat\appdata\roaming\python\python39\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: colorama in c:\users\izzat\appdata\roaming\python\python39\site-packages (from click>=7.0->streamlit) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from pydeck>=0.1.dev5->streamlit) (7.7.0)
# Requirement already satisfied: traitlets>=4.3.2 in c:\python39\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.2.2.post1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from pydeck>=0.1.dev5->streamlit) (6.13.0)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from packaging->streamlit) (3.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->streamlit) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests->streamlit) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python39\lib\site-packages (from requests->streamlit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests->streamlit) (3.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from rich->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from rich->streamlit) (2.12.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\python39\lib\site-packages (from tzlocal->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\python39\lib\site-packages (from tzlocal->streamlit) (2022.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from validators->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.6.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (8.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: psutil in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python39\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.1)
# Requirement already satisfied: backcall in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.29)
# Requirement already satisfied: setuptools>=18.5 in c:\python39\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (57.4.0)
# Requirement already satisfied: stack-data in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.3.0)
# Requirement already satisfied: fastjsonschema in c:\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.15.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\python39\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (304)
# Requirement already satisfied: argon2-cffi in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: wcwidth in c:\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: executing in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.11.1)
# Requirement already satisfied: bleach in c:\users\izzat\appdata\roaming\python\python39\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\izzat\appdata\roaming\python\python39\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\izzat\appdata\roaming\python\python39\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python39\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %%
# %pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\izzat\appdata\roaming\python\python39\site-packages (0.15.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from folium) (1.22.3)
# Requirement already satisfied: requests in c:\python39\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: xyzservices in c:\python39\lib\site-packages (from folium) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests->folium) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python39\lib\site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests->folium) (3.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %%
# %pip install streamlit-folium
# Out:
# Requirement already satisfied: streamlit-folium in c:\python39\lib\site-packages (0.11.0)
# Requirement already satisfied: streamlit>=1.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit-folium) (1.10.0)
# Requirement already satisfied: folium>=0.13 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit-folium) (0.15.1)
# Requirement already satisfied: jinja2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit-folium) (3.1.2)
# Requirement already satisfied: branca in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit-folium) (0.7.1)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from folium>=0.13->streamlit-folium) (1.22.3)
# Requirement already satisfied: requests in c:\python39\lib\site-packages (from folium>=0.13->streamlit-folium) (2.27.1)
# Requirement already satisfied: xyzservices in c:\python39\lib\site-packages (from folium>=0.13->streamlit-folium) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2->streamlit-folium) (2.1.1)
# Requirement already satisfied: altair>=3.2.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (4.2.0)
# Requirement already satisfied: attrs in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (21.4.0)
# Requirement already satisfied: blinker in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (1.7.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (5.2.0)
# Requirement already satisfied: click>=7.0 in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (4.11.4)
# Requirement already satisfied: packaging in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (21.3)
# Requirement already satisfied: pandas>=0.21.0 in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (9.1.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (3.20.3)
# Requirement already satisfied: pyarrow in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (8.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (0.7.1)
# Requirement already satisfied: pympler>=0.9 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (1.0.1)
# Requirement already satisfied: python-dateutil in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (2.8.2)
# Requirement already satisfied: toml in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (6.1)
# Requirement already satisfied: tzlocal in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (4.2)
# Requirement already satisfied: validators in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (3.1.27)
# Requirement already satisfied: typing-extensions in c:\python39\lib\site-packages (from streamlit>=1.2->streamlit-folium) (4.9.0)
# Requirement already satisfied: semver in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (2.13.0)
# Requirement already satisfied: rich in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (12.4.4)
# Requirement already satisfied: watchdog in c:\users\izzat\appdata\roaming\python\python39\site-packages (from streamlit>=1.2->streamlit-folium) (4.0.0)
# Requirement already satisfied: entrypoints in c:\users\izzat\appdata\roaming\python\python39\site-packages (from altair>=3.2.0->streamlit>=1.2->streamlit-folium) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\python39\lib\site-packages (from altair>=3.2.0->streamlit>=1.2->streamlit-folium) (4.6.0)
# Requirement already satisfied: toolz in c:\users\izzat\appdata\roaming\python\python39\site-packages (from altair>=3.2.0->streamlit>=1.2->streamlit-folium) (0.11.2)
# Requirement already satisfied: colorama in c:\users\izzat\appdata\roaming\python\python39\site-packages (from click>=7.0->streamlit>=1.2->streamlit-folium) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from gitpython!=3.1.19->streamlit>=1.2->streamlit-folium) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from importlib-metadata>=1.4->streamlit>=1.2->streamlit-folium) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=0.21.0->streamlit>=1.2->streamlit-folium) (2022.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (7.7.0)
# Requirement already satisfied: traitlets>=4.3.2 in c:\python39\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (5.2.2.post1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (6.13.0)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil->streamlit>=1.2->streamlit-folium) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from packaging->streamlit>=1.2->streamlit-folium) (3.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->folium>=0.13->streamlit-folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests->folium>=0.13->streamlit-folium) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python39\lib\site-packages (from requests->folium>=0.13->streamlit-folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests->folium>=0.13->streamlit-folium) (3.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from rich->streamlit>=1.2->streamlit-folium) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from rich->streamlit>=1.2->streamlit-folium) (2.12.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\python39\lib\site-packages (from tzlocal->streamlit>=1.2->streamlit-folium) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\python39\lib\site-packages (from tzlocal->streamlit>=1.2->streamlit-folium) (2022.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from validators->streamlit>=1.2->streamlit-folium) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=1.2->streamlit-folium) (5.0.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.6.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (8.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (7.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.1.3)
# Requirement already satisfied: psutil in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.5.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python39\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=1.2->streamlit-folium) (0.18.1)
# Requirement already satisfied: backcall in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (3.0.29)
# Requirement already satisfied: setuptools>=18.5 in c:\python39\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (57.4.0)
# Requirement already satisfied: stack-data in c:\users\izzat\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (22.3.0)
# Requirement already satisfied: fastjsonschema in c:\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (2.15.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (6.4.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\python39\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (304)
# Requirement already satisfied: argon2-cffi in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (6.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\users\izzat\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.14.1)
# Requirement already satisfied: wcwidth in c:\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.5)
# Requirement already satisfied: executing in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\izzat\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (4.11.1)
# Requirement already satisfied: bleach in c:\users\izzat\appdata\roaming\python\python39\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\izzat\appdata\roaming\python\python39\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.6.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.1.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\izzat\appdata\roaming\python\python39\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python39\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (0.5.1)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=1.2->streamlit-folium) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)

# %%
import streamlit as st
import requests
import folium
from streamlit_folium import folium_static

# %%
import streamlit as st
import requests
import folium
from streamlit_folium import folium_static

def fetch_outlets():
    response = requests.get("http://localhost:5000/outlets")  # Adjust URL as needed
    if response.status_code == 200:
        return response.json()
    else:
        st.error("Failed to fetch outlet data")
        return []
    
def main():
    st.title("Outlet Map")

    # Fetch outlet data
    outlets = fetch_outlets()

    # Create a map centered at Kuala Lumpur
    m = folium.Map(location=[3.139, 101.6869], zoom_start=12)

    # Add markers for each outlet
    for outlet in outlets:
        folium.Marker(location=[outlet['latitude'], outlet['longitude']],
                      popup=outlet['name']).add_to(m)

    # Render the map
    folium_static(m)

if __name__ == "__main__":
    main()

# %%
def main():
    st.title("Outlet Map")

    # Fetch outlet data
    outlets = fetch_outlets()

    # Create a map centered at Kuala Lumpur
    m = folium.Map(location=[3.139, 101.6869], zoom_start=12)

    # Add markers for each outlet
    for outlet in outlets:
        folium.Marker(location=[outlet['latitude'], outlet['longitude']],
                      popup=outlet['name']).add_to(m)

    # Render the map
    folium_static(m)

if __name__ == "__main__":
    main()
# Out:
# 2024-02-27 00:29:50.574
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\izzat\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Python39\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Python39\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Python39\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File c:\Python39\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File c:\Python39\lib\http\client.py:1279, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1278 """Send a complete request to the server."""
# -> 1279 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Python39\lib\http\client.py:1325, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1324     body = _encode(body, 'body')
# -> 1325 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Python39\lib\http\client.py:1274, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1273     raise CannotSendHeader()
# -> 1274 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Python39\lib\http\client.py:1034, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1033 del self._buffer[:]
# -> 1034 self.send(msg)
#    1036 if message_body is not None:
#    1037
#    1038     # create a consistent interface to message_body
#
# File c:\Python39\lib\http\client.py:974, in HTTPConnection.send(self, data)
#     973 if self.auto_open:
# --> 974     self.connect()
#     975 else:
#
# File c:\Python39\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File c:\Python39\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001E73080E6A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Python39\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File c:\Python39\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File c:\Python39\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /outlets (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E73080E6A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [6], in <cell line: 18>()
#      16     folium_static(m)
#      18 if __name__ == "__main__":
# ---> 19     main()
#
# Input In [6], in main()
#       2 st.title("Outlet Map")
#       4 # Fetch outlet data
# ----> 5 outlets = fetch_outlets()
#       7 # Create a map centered at Kuala Lumpur
#       8 m = folium.Map(location=[3.139, 101.6869], zoom_start=12)
#
# Input In [5], in fetch_outlets()
#       1 def fetch_outlets():
# ----> 2     response = requests.get("http://localhost:5000/outlets")  # Adjust URL as needed
#       3     if response.status_code == 200:
#       4         return response.json()
#
# File c:\Python39\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File c:\Python39\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File c:\Python39\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File c:\Python39\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File c:\Python39\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /outlets (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E73080E6A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
